# %% [markdown]
# # Excersise on various Visualization Techniques

# %% [markdown]
# The iris dataset contains measurements for 150 iris flowers from three different species.
#
#
# The three classes in the Iris dataset:
# Iris-setosa (n=50)
# Iris-versicolor (n=50)
# Iris-virginica (n=50)
# The four features of the Iris dataset:
# sepal length in cm
# sepal width in cm
# petal length in cm
# petal width in cm
#
#
# Get the data
# *Use seaborn to get the iris data by using: iris = sns.load_dataset('iris') *

# %% [raw]
# Import the necessary librairies for visualizing / plotting the graphs as shown below

# %%
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
clear

# %%
iris=sns.load_dataset('iris')
sns.pairplot(iris,hue='species',hue_order=['virginica','versicolor','setosa'])

# %% [markdown]
# Create a kde plot of sepal_length versus sepal width for setosa species of flower.

# %%
sns.kdeplot(iris[iris.species == "setosa"]["sepal_width"], iris[iris.species == "setosa"]["sepal_length"], shade = True, cmap = "plasma", shade_lowest = False)

# %% [raw]
# # Use seaborn to get the tips data by using: tips = sns.load_dataset('tips') *

# %%
clear

# %%
tips['tip_pct'] = 100 * tips['tip'] / tips['total_bill']

grid = sns.FacetGrid(tips, row="sex", col="time", margin_titles=True)
grid.map(plt.hist, "tip_pct", bins=np.linspace(0, 40, 15))

# %%
sns.catplot(x='day',y='total_bill',data=tips,kind='box',hue='sex')

# %%
sns.jointplot('total_bill','tip',data=tips,kind='hex')

# %%
sns.jointplot("total_bill", "tip", data=tips, kind='reg')

# %% [raw]
# # Solve the following Questions using matplot library

# %%
x = np.linspace(0,10,100)
y = x
plt.plot(x, y, '-b', label='linear')
plt.legend(loc='upper left')
plt.show()

# %%
clear

# %%
x = np.linspace(1.0, 2.0, 1000)
y = 10 * x
plt.plot(x, y, color = "steelblue")
s = np.linspace(2.0, 4.0, 1000)
t = (5 * s) + 10
plt.plot(s, t, color = "steelblue")

plt.xlim(0.5, 4.5)
plt.ylim(0, 35)

plt.plot(4,25, marker = "^", color = "green")
plt.plot(2.5, 25, marker = "^", color = "green")
plt.plot(1.35, 10, marker = "^", color = "green")

# %%
clear

# %%
x = np.arange(0,3*np.pi+(np.pi)/2,0.1)
y = np.sin(x)
z = np.cos(x)

plt.plot(x,y)
plt.plot(x,z,linestyle='dashed')
plt.show()

# %%
fig = plt.figure()
x=np.linspace(0,10,1000)
y1=np.exp(x)
ax1 = fig.add_subplot(121)
ax1.plot(x,y,x,0*x)

y2=np.log(x)
y3=np.exp(0.95 * x)

ax2 = fig.add_subplot(122)
plt.yscale('log')
ax2.plot(x,y2,x,y3)

plt.show()
# Out:
# <ipython-input-75-ad5e2bffe616>:7: RuntimeWarning: divide by zero encountered in log
#   y2=np.log(x)

# %%
clear

# %%
clear

# %%
x=np.linspace(-0.75,1,1000)
y=x**3
fig=plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.spines['left'].set_position('center')
ax.spines['bottom'].set_position('zero')
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')
plt.plot(x,y)

# %%
clear

# %%
clear

# %%
clear
